# %% [markdown]
# <a href="https://colab.research.google.com/github/n-prathyusha82/FMML_Assigment/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 05:58:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   208MB/s    in 0.3s
#
# 2024-03-25 05:58:01 (208 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36332   1206.6829v1  We present a class of inequality constraints o...    cs
# 39792  1704.05832v1  We present a novel mapping framework for robot...    cs
# 7087   1710.02766v1  We present a Bayesian extension to convolution...  stat
# 13976  1703.03334v2  For genetic algorithms using a bit-string repr...    cs
# 5938    1305.1809v2  This paper proposes an online tree-based Bayes...  stat
# ...             ...                                                ...   ...
# 22159  1506.02681v3  There is renewed interest in formulating integ...  stat
# 859     1306.2801v4  In this paper, a simple, general method of add...    cs
# 18620   1106.2647v2  Galles and Pearl claimed that "for recursive m...    cs
# 9885    1401.1549v2  Demand response (DR) for residential and small...    cs
# 21759   1205.3234v5  Hierarchical parametric models consisting of o...  stat
#
#                                                    title  year  \
# 36332  Inequality Constraints in Causal Models with H...  2012
# 39792  SkiMap: An Efficient Mapping Framework for Rob...  2017
# 7087   Bayesian Alignments of Warped Multi-Output Gau...  2017
# 13976                            Fast Genetic Algorithms  2017
# 5938          Cover Tree Bayesian Reinforcement Learning  2013
# ...                                                  ...   ...
# 22159  Frank-Wolfe Bayesian Quadrature: Probabilistic...  2015
# 859    Understanding Dropout: Training Multi-Layer Pe...  2013
# 18620    From Causal Models To Counterfactual Structures  2011
# 9885   Optimal Demand Response Using Device Based Rei...  2014
# 21759  Asymptotic Accuracy of Bayes Estimation for La...  2012
#
#                                                 keywords
# 36332  [inequality, constraints, distributions, inter...
# 39792  [framework, navigation, representations, occup...
# 7087   [extension, convolution, processes, representa...
# 13976  [algorithms, representation, recommendation, j...
# 5938   [reinforcement, inference, generalised, distri...
# ...                                                  ...
# 22159  [formulating, integration, inference, motivate...
# 859    [auxiliary, stochastic, perceptron, generaliza...
# 18620  [recursive, framework, restrictions, counterfa...
# 9885   [residential, commercial, buildings, estimated...
# 21759  [hierarchical, parametric, consisting, observa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36332    [inequality, constraints, distributions, inter...
# 39792    [framework, navigation, representations, occup...
# 7087     [extension, convolution, processes, representa...
# 13976    [algorithms, representation, recommendation, j...
# 5938     [reinforcement, inference, generalised, distri...
#                                ...
# 6668     [classification, challenging, dimensional, cor...
# 10804    [constrained, stochastic, considered, conditio...
# 26481    [confounding, recognition, distinctiveness, ch...
# 9611     [dimensional, subspaces, spherically, symmetri...
# 22461    [nonlinear, observations, superposition, mathe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8733 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c7d0533-c177-4867-87b4-947b3311b987" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c7d0533-c177-4867-87b4-947b3311b987")) {                    Plotly.newPlot(                        "6c7d0533-c177-4867-87b4-947b3311b987",                        [{"x":["observational","instrumental","experiments","inequality","randomized","unmeasured","interventions","distributions","experimental","constraints","applications","variables","optimized","organized","continuously","occupancy","parallelizable","footprint","measurements","representations","integration","efficiency","efficient","computational","structure","framework","inherently","navigation","representation","information","extension","variational","transform","connected","dependent","parametric","recovering","compression","arbitrary","embedding","convolution","alignments","decomposition","interpretable","approximation","functions","functional","observations","generating","processes","evolution","polynomial","exponential","consequently","strategies","annealing","distribution","bipartite","asymptotically","recommendation","programming","evolutionary","optimizes","simulated","algorithm","performance","algorithms","multimodal","deviation","justified","observation","following","sensitive","significantly","multivariate","reinforcement","generalised","constructed","piecewise","simplicity","inference","flexibility","iteration","comparison","approximate","exploration","demonstrate","continuous","environments","dimensional","effective","competitive","graphical","carefully","arithmetic","constrained","penalized","challenge","component","covariance","likelihood","predecessors","competitors","complexity","estimating","estimation","outperforms","challenging","maximizes","numerically","developing","conditioning","consistent","typically","inaccurate","dependencies","dependence","influence","financial","parameters","conditional","covariates","automatically","combining","segmentation","extracted","significant","automatic","topically","furthermore","knowledge","waveforms","recognizer","evaluation","reduction","broadcast","probabilistic","integrating","application","consistency","providing","narrowing","advantage","exploiting","represented","properties","transformations","smoothing","constraint","solutions","computation","generally","represent","different","formulate","potential","particular","classification","manifolds","optimization","recognition","potentially","transport","favorably","extraction","uncertainties","centrality","importance","underlying","distribute","fundamental","predicting","demonstrated","synthetic","eigenvector","inclusion","quantitatively","attributes","tractable","determining","expectation","approximating","classical","basketball","posterior","minimizes","propagation","divergence","alternative","underestimation","estimates","uncertainty","minimizing","minimization","regression","closeness","successful","importantly","extracting","processing"],"y":[10,5,633,12,21,1,7,103,385,157,440,124,52,17,19,5,4,3,46,243,69,154,365,275,318,567,20,33,389,688,92,44,52,77,57,38,26,53,90,104,53,14,61,29,118,228,48,76,103,101,51,62,44,38,103,7,225,6,11,33,110,66,18,63,806,880,578,33,17,8,53,78,57,265,20,110,8,54,13,24,205,26,35,155,102,60,549,110,81,164,236,119,46,32,13,65,10,160,79,23,64,1,3,233,57,201,244,280,12,8,55,11,88,115,10,53,22,58,13,226,77,1,193,97,198,119,236,203,2,177,373,4,8,267,84,5,155,43,241,51,81,3,92,73,86,228,48,18,96,141,121,62,122,726,47,153,258,545,14,301,384,49,13,19,141,14,5,76,114,3,89,84,83,139,1,11,23,66,25,37,40,18,94,2,33,8,60,34,106,0,80,79,50,64,100,3,67,22,60,282],"type":"bar"},{"x":["observational","instrumental","experiments","inequality","randomized","u ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Digital</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>Ecosystems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style=''>of</span> <span style=''>Evolving</span> <span style=''>Agent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Populations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style=''>is</span> <span style=''>perhaps</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>features</span> <span style=''>of</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineered</span> <span style=''>system</span> <span style=''>given</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>being</span> <span style=''>able</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>its</span> <span style=''>response</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740744);'>environmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>prior</span> <span style=''>to</span> <span style=''>actual</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>deployment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Engineered</span> <span style=''>systems</span> <span style=''>are</span> <span style=''>becoming</span> <span style=''>ever</span> <span style=''>more</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>approaching</span> <span style=''>the</span> <span style=''>same</span> <span style=''>levels</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>ecosystems</span> <span style=''>and</span> <span style=''>so</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>becomes</span> <span style=''>ever</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>but</span> <span style=''>taking</span> <span style=''>on</span> <span style=''>more</span> <span style=''>and</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style=''>dynamics</span> <span style=''>can</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>an</span> <span style=''>ever</span> <span style=''>more</span> <span style=''>elusive</span> <span style=''>property</span> <span style=''>The</span> <span style=''>Chli</span> <span style=''>DeWilde</span> <span style='background-color:rgba(0, 255, 0, 0.38235294117647056);'>definition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>views</span> <span style=''>a</span> <span style=''>Multi</span> <span style=''>Agent</span> <span style=''>System</span> <span style=''>as</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>time</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>With</span> <span style=''>a</span> <span style=''>Multi</span> <span style=''>Agent</span> <span style=''>System</span> <span style=''>being</span> <span style='background-color:rgba(0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Slice</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>Gaussian</span> <span style=''>models</span> <br/><br/><span style=''>The</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>way</span> <span style=''>to</span> <span style=''>specify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>between</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>In</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>using</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Integrating</span> <span style=''>over</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>possible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</span> <span style=''>when</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>using</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style=''>sampling</span> <span style=''>However</span> <span style=''>with</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>require</span> <span style=''>careful</span> <span style=''>tuning</span> <span style=''>and</span> <span style=''>may</span> <span style=''>converge</span> <span style=''>slowly</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>slice</span> <span style=''>sampling</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>requires</span> <span style=''>little</span> <span style=''>tuning</span> <span style=''>while</span> <span style=''>mixing</span> <span style=''>well</span> <span style=''>in</span> <span style=''>both</span> <span style=''>strong</span> <span style=''>and</span> <span style=''>weak</span> <span style=''>data</span> <span style=''>regimes</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stabilizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Nets</span> <span style=''>With</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>Methods</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>solve</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>data</span> <span style=''>science</span> <span style=''>but</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>notoriously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>train</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>difficulties</span> <span style=''>come</span> <span style=''>from</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>optimal</span> <span style=''>weights</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>nets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>and</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>minimizers</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3381294964028776);'>stochastic</span> <span style=''>gradient</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>used</span> <span style=''>for</span> <span style=''>such</span> <span style=''>problems</span> <span style=''>do</span> <span style=''>not</span> <span style=''>reliably</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>and</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.4149253731343283);'>convergence</span> <span style=''>does</span> <span style=''>happen</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modification</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3381294964028776);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>stabilizes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>show</span> <span style=''>both</span> <span style=''>in</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>practice</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>reliably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>and</span> <span style=''>is</span> <span style=''>stable</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <span style=''>of</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Electronic</span> <span style=''>Medical</span> <span style=''>Record</span> <span style=''>Quality</span> <br/><br/><span style=''>There</span> <span style=''>is</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>applying</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Electronic</span> <span style=''>Medical</span> <span style=''>Records</span> <span style=''>(EMR)</span> <span style=''>Across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>institutions</span> <span style=''>however</span> <span style=''>EMR</span> <span style=''>quality</span> <span style=''>can</span> <span style=''>vary</span> <span style=''>widely</span> <span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disparity</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>three</span> <span style=''>advanced</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilayer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceptron</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>The</span> <span style=''>EMR</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disparity</span> <span style=''>was</span> <span style=''>emulated</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EMR</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Childrens</span> <span style=''>Hospital</span> <span style=''>Los</span> <span style=''>Angeles</span> <span style=''>(CHLA)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Pediatric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intensive</span> <span style=''>Care</span> <span style=''>Unit</span> <span style=''>(PICU)</span> <span style=''>and</span> <span style=''>Cardiothoracic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intensive</span> <span style=''>Care</span> <span style=''>Unit</span> <span style=''>(CTICU)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>were</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>patients</span> <span style=''>from</span> <span style=''>the</span> <span style=''>PICU</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>in</span> <span style=''>ICU</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>for</span> <span style=''>patients</span> <span style=''>in</span> <span style=''>a</span> <span style=''>held</span> <span style=''>out</span> <span style=''>set< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10021321961620469)
# 	architecture (0.08813077469793888)
# 	knowledge (0.13255152807391613)
# 	challenging (0.09950248756218906)
# 	segmentation (0.07036247334754797)
# 	information (0.24449182658137883)
# 	different (0.2579957356076759)
# 	detection (0.12117981520966596)
# 	recognition (0.13646055437100213)
# 	convolutional (0.14463397299218195)
#
# Some Statistics words are:
# 	stochastic (0.1404833836858006)
# 	algorithm (0.38016112789526685)
# 	variables (0.14400805639476336)
# 	theoretical (0.15307150050352467)
# 	statistical (0.15609264853977844)
# 	estimation (0.17623363544813697)
# 	distribution (0.18882175226586104)
# 	dimensional (0.19133937562940584)
# 	inference (0.2079556898288016)
# 	regression (0.17925478348439072)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="04224d78-4ee6-4382-8b1f-69f238aca79d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04224d78-4ee6-4382-8b1f-69f238aca79d")) {                    Plotly.newPlot(                        "04224d78-4ee6-4382-8b1f-69f238aca79d",                        [{"x":["observational","instrumental","experiments","inequality","randomized","unmeasured","interventions","distributions","experimental","constraints","applications","variables","optimized","organized","continuously","occupancy","parallelizable","footprint","measurements","representations","integration","efficiency","efficient","computational","structure","framework","inherently","navigation","representation","information","extension","variational","transform","connected","dependent","parametric","recovering","compression","arbitrary","embedding","convolution","alignments","decomposition","interpretable","approximation","functions","functional","observations","generating","processes","evolution","polynomial","exponential","consequently","strategies","annealing","distribution","bipartite","asymptotically","recommendation","programming","evolutionary","optimizes","simulated","algorithm","performance","algorithms","multimodal","deviation","justified","observation","following","sensitive","significantly","multivariate","reinforcement","generalised","constructed","piecewise","simplicity","inference","flexibility","iteration","comparison","approximate","exploration","demonstrate","continuous","environments","dimensional","effective","competitive","graphical","carefully","arithmetic","constrained","penalized","challenge","component","covariance","likelihood","predecessors","competitors","complexity","estimating","estimation","outperforms","challenging","maximizes","numerically","developing","conditioning","consistent","typically","inaccurate","dependencies","dependence","influence","financial","parameters","conditional","covariates","automatically","combining","segmentation","extracted","significant","automatic","topically","furthermore","knowledge","waveforms","recognizer","evaluation","reduction","broadcast","probabilistic","integrating","application","consistency","providing","narrowing","advantage","exploiting","represented","properties","transformations","smoothing","constraint","solutions","computation","generally","represent","different","formulate","potential","particular","classification","manifolds","optimization","recognition","potentially","transport","favorably","extraction","uncertainties","centrality","importance","underlying","distribute","fundamental","predicting","demonstrated","synthetic","eigenvector","inclusion","quantitatively","attributes","tractable","determining","expectation","approximating","classical","basketball","posterior","minimizes","propagation","divergence","alternative","underestimation","estimates","uncertainty","minimizing","minimization","regression","closeness","successful","importantly","extracting","processing","selection","mechanism","conducted","characteristics","attention","infeasible","extensive","meanwhile","benchmark","discriminative","incapable","introduce","separately","standalone","projection","processor","character","recognize","accurately","artificial","experiment","collected","characters","convolutional","architecture","annotations","frameworks","designing","additional","auxiliary","supervised","approaches","supervision","initialization","available","asymmetric","localization","subroutine","reconstructs","currently","empirical","benchmarks","incremental","cognitive","distributed","extending","contribute","sometimes","technological","technology","interactive","computing","cognition","capacities","distributing","understanding","t ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underestimation
# 	subroutine
# 	sparsistency
# 	chemometrics
# 	privately
# 	accommodates
# 	jackknife
# 	cytometry
# 	borrowing
# 	thetastar
# 	emphdirectly
# 	refitting
# 	unprocessed
# 	reassignment
# 	thresholded
# 	unplanned
# 	readmission
# 	undetermined
# 	solvation
# 	archetypes
# Some words which never appear in Statistics papers:
# 	topically
# 	recognizer
# 	standalone
# 	capacities
# 	telecommunications
# 	interactivity
# 	colleagues
# 	intellectual
# 	roughness
# 	presently
# 	transcriptions
# 	thereafter
# 	nonadaptive
# 	extraversion
# 	deliberately
# 	occlusions
# 	illuminations
# 	responded
# 	luminance
# 	subjectively

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.057355998532469e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
